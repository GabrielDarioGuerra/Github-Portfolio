# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### DATA INITIALIZATION

# %%
import pandas as pd
# Read the data from the CSV file
players_df = pd.read_csv('/content/drive/My Drive/Dataset/players.csv')
plays_df =pd.read_csv('/content/drive/My Drive/Dataset/plays.csv')
tackles_df = pd.read_csv('/content/drive/My Drive/Dataset/tackles.csv')
tracking_week_1_df = pd.read_csv('/content/drive/My Drive/Dataset/tracking_week_1.csv')

# %%
# import pandas as pd
# import os

# # Define the path to the folder containing the CSV files
# # csv_folder = 'csv files'

# # Load each CSV file into a separate DataFrame
# # games_df = pd.read_csv(os.path.join(csv_folder, 'games.csv'))
# players_df = pd.read_csv(os.path.join(csv_folder, 'players.csv'))
# plays_df = pd.read_csv(os.path.join(csv_folder, 'plays.csv'))
# tackles_df = pd.read_csv(os.path.join(csv_folder, 'tackles.csv'))
# tracking_week_1_df = pd.read_csv(os.path.join(csv_folder, 'tracking_week_1.csv'))
# # tracking_week_2_df = pd.read_csv(os.path.join(csv_folder, 'tracking_week_2.csv'))
# # tracking_week_3_df = pd.read_csv(os.path.join(csv_folder, 'tracking_week_3.csv'))
# # tracking_week_4_df = pd.read_csv(os.path.join(csv_folder, 'tracking_week_4.csv'))
# # tracking_week_5_df = pd.read_csv(os.path.join(csv_folder, 'tracking_week_5.csv'))
# # tracking_week_6_df = pd.read_csv(os.path.join(csv_folder, 'tracking_week_6.csv'))
# # tracking_week_7_df = pd.read_csv(os.path.join(csv_folder, 'tracking_week_7.csv'))
# # tracking_week_8_df = pd.read_csv(os.path.join(csv_folder, 'tracking_week_8.csv'))
# # tracking_week_9_df = pd.read_csv(os.path.join(csv_folder, 'tracking_week_9.csv'))

# %%
players_df.columns
# Out:
# Index(['nflId', 'height', 'weight', 'birthDate', 'collegeName', 'position',
#        'displayName'],
#       dtype='object')

# %%
tackles_df.columns
# Out:
# Index(['gameId', 'playId', 'nflId', 'tackle', 'assist', 'forcedFumble',
#        'pff_missedTackle'],
#       dtype='object')

# %%
plays_df.columns
# Out:
# Index(['gameId', 'playId', 'ballCarrierId', 'ballCarrierDisplayName',
#        'playDescription', 'quarter', 'down', 'yardsToGo', 'possessionTeam',
#        'defensiveTeam', 'yardlineSide', 'yardlineNumber', 'gameClock',
#        'preSnapHomeScore', 'preSnapVisitorScore', 'passResult', 'passLength',
#        'penaltyYards', 'prePenaltyPlayResult', 'playResult',
#        'playNullifiedByPenalty', 'absoluteYardlineNumber', 'offenseFormation',
#        'defendersInTheBox', 'passProbability', 'preSnapHomeTeamWinProbability',
#        'preSnapVisitorTeamWinProbability', 'homeTeamWinProbabilityAdded',
#        'visitorTeamWinProbilityAdded', 'expectedPoints', 'expectedPointsAdded',
#        'foulName1', 'foulName2', 'foulNFLId1', 'foulNFLId2'],
#       dtype='object')

# %%
# tracking_week_1_df
# tackles_df['attack'] = tackles_df[['tackle', 'assist', 'forcedFumble']].max(axis=1)

# %%
tracking_week_1_df
# Out:
#              gameId  playId    nflId     displayName  frameId  \
# 0        2022090800      56  35472.0  Rodger Saffold        1
# 1        2022090800      56  35472.0  Rodger Saffold        2
# 2        2022090800      56  35472.0  Rodger Saffold        3
# 3        2022090800      56  35472.0  Rodger Saffold        4
# 4        2022090800      56  35472.0  Rodger Saffold        5
# ...             ...     ...      ...             ...      ...
# 1407434  2022091200    3826      NaN        football       49
# 1407435  2022091200    3826      NaN        football       50
# 1407436  2022091200    3826      NaN        football       51
# 1407437  2022091200    3826      NaN        football       52
# 1407438  2022091200    3826      NaN        football       53
#
#                                time  jerseyNumber      club playDirection  \
# 0        2022-09-08 20:24:05.200000          76.0       BUF          left
# 1        2022-09-08 20:24:05.299999          76.0       BUF          left
# 2        2022-09-08 20:24:05.400000          76.0       BUF          left
# 3        2022-09-08 20:24:05.500000          76.0       BUF          left
# 4        2022-09-08 20:24:05.599999          76.0       BUF          left
# ...                             ...           ...       ...           ...
# 1407434  2022-09-12 23:05:57.799999           NaN  football          left
# 1407435  2022-09-12 23:05:57.900000           NaN  football          left
# 1407436  2022-09-12 23:05:58.000000           NaN  football          left
# 1407437  2022-09-12 23:05:58.099999           NaN  football          left
# 1407438  2022-09-12 23:05:58.200000           NaN  football          left
#
#                  x      y     s     a   dis       o     dir         event
# 0        88.370000  27.27  1.62  1.15  0.16  231.74  147.90           NaN
# 1        88.470000  27.13  1.67  0.61  0.17  230.98  148.53  pass_arrived
# 2        88.560000  27.01  1.57  0.49  0.15  230.98  147.05           NaN
# 3        88.640000  26.90  1.44  0.89  0.14  232.38  145.42           NaN
# 4        88.720000  26.80  1.29  1.24  0.13  233.36  141.95           NaN
# ...            ...    ...   ...   ...   ...     ...     ...           ...
# 1407434  56.220001   9.89  2.56  1.25  0.25     NaN     NaN        tackle
# 1407435  56.060001  10.08  2.50  1.14  0.24     NaN     NaN           NaN
# 1407436  55.889999  10.27  2.38  1.70  0.25     NaN     NaN           NaN
# 1407437  55.730000  10.44  2.07  2.83  0.24     NaN     NaN           NaN
# 1407438  55.570000  10.57  1.86  3.00  0.20     NaN     NaN           NaN
#
# [1407439 rows x 17 columns]

# %%
final_df = pd.merge(tackles_df, tracking_week_1_df, on=['playId','gameId','nflId'], how='left')
print(final_df.shape)
final_df.head()
# Out:
# (108376, 21)
#        gameId  playId  nflId  tackle  assist  forcedFumble  pff_missedTackle  \
# 0  2022090800     101  42816       1       0             0                 0
# 1  2022090800     101  42816       1       0             0                 0
# 2  2022090800     101  42816       1       0             0                 0
# 3  2022090800     101  42816       1       0             0                 0
# 4  2022090800     101  42816       1       0             0                 0
#
#   displayName  frameId                        time  ...  club playDirection  \
# 0   Troy Hill      1.0  2022-09-08 20:25:08.200000  ...    LA          left
# 1   Troy Hill      2.0  2022-09-08 20:25:08.299999  ...    LA          left
# 2   Troy Hill      3.0  2022-09-08 20:25:08.400000  ...    LA          left
# 3   Troy Hill      4.0  2022-09-08 20:25:08.500000  ...    LA          left
# 4   Troy Hill      5.0  2022-09-08 20:25:08.599999  ...    LA          left
#
#        x      y     s     a   dis       o     dir  event
# 0  64.67  40.76  0.06  0.55  0.01  112.17  108.97    NaN
# 1  64.67  40.77  0.08  0.56  0.01  109.90    7.85    NaN
# 2  64.66  40.79  0.20  0.68  0.02  105.18  356.70    NaN
# 3  64.66  40.81  0.30  0.59  0.03  102.25    0.46    NaN
# 4  64.66  40.85  0.40  0.43  0.04  100.21    0.20    NaN
#
# [5 rows x 21 columns]

# %%
# final_df = final_df.drop(columns=['tackle', 'assist', 'forcedFumble', 'pff_missedTackle'])

# %%
final_dff = pd.merge(plays_df,final_df,on=['playId','gameId'], how='left')
print(final_dff.shape)
final_dff.head()
# Out:
# (108837, 54)
#        gameId  playId  ballCarrierId ballCarrierDisplayName  \
# 0  2022100908    3537          48723           Parker Hesse
# 1  2022091103    3126          52457         Chase Claypool
# 2  2022091103    3126          52457         Chase Claypool
# 3  2022091103    3126          52457         Chase Claypool
# 4  2022091103    3126          52457         Chase Claypool
#
#                                      playDescription  quarter  down  \
# 0  (7:52) (Shotgun) M.Mariota pass short middle t...        4     1
# 1  (7:38) (Shotgun) C.Claypool right end to PIT 3...        4     1
# 2  (7:38) (Shotgun) C.Claypool right end to PIT 3...        4     1
# 3  (7:38) (Shotgun) C.Claypool right end to PIT 3...        4     1
# 4  (7:38) (Shotgun) C.Claypool right end to PIT 3...        4     1
#
#    yardsToGo possessionTeam defensiveTeam  ... club  playDirection      x  \
# 0         10            ATL            TB  ...  NaN            NaN    NaN
# 1         10            PIT           CIN  ...  CIN           left  68.68
# 2         10            PIT           CIN  ...  CIN           left  68.63
# 3         10            PIT           CIN  ...  CIN           left  68.59
# 4         10            PIT           CIN  ...  CIN           left  68.56
#
#        y     s     a   dis       o     dir          event
# 0    NaN   NaN   NaN   NaN     NaN     NaN            NaN
# 1  41.56  0.50  0.44  0.05  116.37  296.96            NaN
# 2  41.58  0.48  0.29  0.05  116.37  295.99            NaN
# 3  41.60  0.43  0.32  0.04  117.55  297.11            NaN
# 4  41.62  0.41  0.34  0.04  117.55  302.03  man_in_motion
#
# [5 rows x 54 columns]

# %%
final_dff.columns
# Out:
# Index(['gameId', 'playId', 'ballCarrierId', 'ballCarrierDisplayName',
#        'playDescription', 'quarter', 'down', 'yardsToGo', 'possessionTeam',
#        'defensiveTeam', 'yardlineSide', 'yardlineNumber', 'gameClock',
#        'preSnapHomeScore', 'preSnapVisitorScore', 'passResult', 'passLength',
#        'penaltyYards', 'prePenaltyPlayResult', 'playResult',
#        'playNullifiedByPenalty', 'absoluteYardlineNumber', 'offenseFormation',
#        'defendersInTheBox', 'passProbability', 'preSnapHomeTeamWinProbability',
#        'preSnapVisitorTeamWinProbability', 'homeTeamWinProbabilityAdded',
#        'visitorTeamWinProbilityAdded', 'expectedPoints', 'expectedPointsAdded',
#        'foulName1', 'foulName2', 'foulNFLId1', 'foulNFLId2', 'nflId', 'tackle',
#        'assist', 'forcedFumble', 'pff_missedTackle', 'displayName', 'frameId',
#        'time', 'jerseyNumber', 'club', 'playDirection', 'x', 'y', 's', 'a',
#        'dis', 'o', 'dir', 'event'],
#       dtype='object')

# %%
final_df = final_dff.drop(['gameId','nflId', 'playId','playDirection','displayName','forcedFumble','pff_missedTackle','club','event','jerseyNumber','possessionTeam','defensiveTeam','foulNFLId2','foulNFLId1', 'foulName2','foulName1', 'expectedPoints', 'expectedPointsAdded','passResult', 'passLength','penaltyYards', 'prePenaltyPlayResult', 'playResult','playNullifiedByPenalty', 'absoluteYardlineNumber', 'offenseFormation','ballCarrierId', 'ballCarrierDisplayName','playDescription', 'yardlineSide', 'gameClock'], axis = 1)
# 'expectedPoints', 'expectedPointsAdded','passResult', 'passLength','penaltyYards', 'prePenaltyPlayResult', 'playResult','playNullifiedByPenalty', 'absoluteYardlineNumber', 'offenseFormation','ballCarrierId', 'ballCarrierDisplayName','playDescription', 'yardlineSide', 'gameClock'

# %%
# def convert_height_to_meters(height):
#     # Split the height into feet and inches
#     feet, inches = map(int, height.split('-'))
#     # Convert height to inches
#     total_inches = feet * 12 + inches
#     # Convert inches to cm (1 inch = 2.54 cm)
#     height_cm = total_inches * 2.54
#     # Convert cm to meters
#     height_m = height_cm / 100
#     return height_m

# final_df['height_m'] = final_df['height'].apply(convert_height_to_meters)
# final_df.sample(4)

# %%
# final_df['x'] = final_df['x'].apply(lambda x : str(x))

# final_df[final_df['x']=="nan"].index

# Convert 'x' column to strings
final_df['x'] = final_df['x'].astype(str)

# Identify rows where 'x' is "nan"
nan_x_indices = final_df[final_df['x'] == "nan"].index

# Remove rows with 'x' as "nan"
final_df = final_df.drop(nan_x_indices)

# Now, you can do the same for the 'y' column if needed
final_df['y'] = final_df['y'].astype(str)
nan_y_indices = final_df[final_df['y'] == "nan"].index
final_df = final_df.drop(nan_y_indices)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93001 entries, 1 to 108829
# Data columns (total 23 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   quarter                           93001 non-null  int64
#  1   down                              93001 non-null  int64
#  2   yardsToGo                         93001 non-null  int64
#  3   yardlineNumber                    93001 non-null  int64
#  4   preSnapHomeScore                  93001 non-null  int64
#  5   preSnapVisitorScore               93001 non-null  int64
#  6   defendersInTheBox                 92978 non-null  float64
#  7   passProbability                   89965 non-null  float64
#  8   preSnapHomeTeamWinProbability     93001 non-null  float64
#  9   preSnapVisitorTeamWinProbability  93001 non-null  float64
#  10  homeTeamWinProbabilityAdded       93001 non-null  float64
#  11  visitorTeamWinProbilityAdded      93001 non-null  float64
#  12  tackle                            93001 non-null  float64
#  13  assist                            93001 non-null  float64
#  14  frameId                           93001 non-null  float64
#  15  time                              93001 non-null  object
#  16  x                                 93001 non-null  object
#  17  y                                 93001 non-null  object
#  18  s                                 93001 non-null  float64
#  19  a                                 93001 non-null  float64
#  20  dis                               93001 non-null  float64
#  21  o                                 93001 non-null  float64
#  22  dir                               93001 non-null  float64
# dtypes: float64(14), int64(6), object(3)
# memory usage: 17.0+ MB

# %%
# Convert 'playDirection' to numerical values
# final_df['playDirection'] = final_df['playDirection'].map({'left': 0, 'right': 1})
# One-hot encode 'club' and 'event' columns
# final_df = pd.get_dummies(final_df, columns=[ 'event'], prefix=['event'])

# # Drop original 'club' and 'event' columns
# final_df = final_df.drop(columns=['event'])

# %%
# time
final_df['time'] = pd.to_numeric(pd.to_datetime(final_df['time']))

# %%
# final_df['time_elapsed'] = (final_df['time'] - final_df['time'].min()).dt.total_seconds()
final_df
# Out:
#         quarter  down  yardsToGo  yardlineNumber  preSnapHomeScore  \
# 1             4     1         10              34                14
# 2             4     1         10              34                14
# 3             4     1         10              34                14
# 4             4     1         10              34                14
# 5             4     1         10              34                14
# ...         ...   ...        ...             ...               ...
# 108825        4     1         10              30                17
# 108826        4     1         10              30                17
# 108827        4     1         10              30                17
# 108828        4     1         10              30                17
# 108829        4     1         10              30                17
#
#         preSnapVisitorScore  defendersInTheBox  passProbability  \
# 1                        20                7.0         0.416454
# 2                        20                7.0         0.416454
# 3                        20                7.0         0.416454
# 4                        20                7.0         0.416454
# 5                        20                7.0         0.416454
# ...                     ...                ...              ...
# 108825                   16                7.0         0.298983
# 108826                   16                7.0         0.298983
# 108827                   16                7.0         0.298983
# 108828                   16                7.0         0.298983
# 108829                   16                7.0         0.298983
#
#         preSnapHomeTeamWinProbability  preSnapVisitorTeamWinProbability  ...  \
# 1                            0.160485                          0.839515  ...
# 2                            0.160485                          0.839515  ...
# 3                            0.160485                          0.839515  ...
# 4                            0.160485                          0.839515  ...
# 5                            0.160485                          0.839515  ...
# ...                               ...                               ...  ...
# 108825                       0.615241                          0.384759  ...
# 108826                       0.615241                          0.384759  ...
# 108827                       0.615241                          0.384759  ...
# 108828                       0.615241                          0.384759  ...
# 108829                       0.615241                          0.384759  ...
#
#         assist  frameId                 time      x      y     s     a   dis  \
# 1          0.0      1.0  1662910451099999000  68.68  41.56  0.50  0.44  0.05
# 2          0.0      2.0  1662910451200000000  68.63  41.58  0.48  0.29  0.05
# 3          0.0      3.0  1662910451299999000  68.59   41.6  0.43  0.32  0.04
# 4          0.0      4.0  1662910451400000000  68.56  41.62  0.41  0.34  0.04
# 5          0.0      5.0  1662910451500000000  68.52  41.63  0.38  0.29  0.04
# ...        ...      ...                  ...    ...    ...   ...   ...   ...
# 108825     1.0     21.0  1663022853500000000  41.94  18.59  3.20  3.21  0.34
# 108826     1.0     22.0  1663022853599999000  41.93  18.88  2.69  3.92  0.29
# 108827     1.0     23.0  1663022853700000000  41.92  19.12  2.05  4.74  0.24
# 108828     1.0     24.0  1663022853799999000  41.91   19.3  1.50  4.72  0.18
# 108829     1.0     25.0  1663022853900000000   41.9  19.42  0.99  4.45  0.12
#
#              o     dir
# 1       116.37  296.96
# 2       116.37  295.99
# 3       117.55  297.11
# 4       117.55  302.03
# 5       117.55  299.44
# ...        ...     ...
# 108825    0.30  358.37
# 108826  353.56  356.64
# 108827    2.14  357.57
# 108828    3.66  357.42
# 108829    3.66  353.75
#
# [93001 rows x 23 columns]

# %% [markdown]
# ### Feature engineering

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, recall_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

# %%
# columns_to_encode = [ 'possessionTeam', 'defensiveTeam']
# # Dictionary to store mappings
# encoding_mappings = {}
# # Encode each column
# label_encoder = LabelEncoder()
# for column in columns_to_encode:
#     # Fill NaN values with a placeholder before encoding
#     final_df[column].fillna('NaN', inplace=True)

#     # Fit and transform with LabelEncoder
#     final_df[column] = label_encoder.fit_transform(final_df[column])

#     # Store the mappings
#     encoding_mappings[column] = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))

# %%
import matplotlib.pyplot as plt
import seaborn as sns

correlation_final_df = final_df.corr()
# Display the correlation values
print(correlation_final_df)
# Calculate the correlation matrix
correlation_matrix = final_df.corr()
# Set up the matplotlib figure
plt.figure(figsize=(12, 10))
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
# Show the plot
plt.show()
# Out:
# <ipython-input-21-731934e49acd>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_final_df = final_df.corr()
# <ipython-input-21-731934e49acd>:8: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = final_df.corr()
#                                    quarter      down  yardsToGo  \
# quarter                           1.000000 -0.004144   0.004334
# down                             -0.004144  1.000000  -0.477850
# yardsToGo                         0.004334 -0.477850   1.000000
# yardlineNumber                   -0.008579  0.054347  -0.006087
# preSnapHomeScore                  0.737434 -0.037874   0.020080
# preSnapVisitorScore               0.657620  0.028971   0.013621
# defendersInTheBox                -0.090144 -0.101572  -0.213700
# passProbability                  -0.118828  0.321263   0.165595
# preSnapHomeTeamWinProbability     0.086341 -0.055746   0.011835
# preSnapVisitorTeamWinProbability -0.086341  0.055746  -0.011835
# homeTeamWinProbabilityAdded      -0.026866 -0.022881   0.035253
# visitorTeamWinProbilityAdded      0.026866  0.022881  -0.035253
# tackle                           -0.004263  0.033815  -0.006896
# assist                           -0.010638 -0.055171   0.017317
# frameId                           0.011445 -0.072899  -0.011410
# time                              0.004730  0.022776  -0.006137
# s                                -0.021146  0.057199   0.047349
# a                                -0.014673  0.052188   0.063469
# dis                              -0.019706  0.058002   0.046967
# o                                 0.017287  0.024167  -0.003324
# dir                              -0.032656  0.003554   0.004571
#
#                                   yardlineNumber  preSnapHomeScore  \
# quarter                                -0.008579          0.737434
# down                                    0.054347         -0.037874
# yardsToGo                              -0.006087          0.020080
# yardlineNumber                          1.000000          0.008974
# preSnapHomeScore                        0.008974          1.000000
# preSnapVisitorScore                     0.001085          0.417302
# defendersInTheBox                      -0.096164         -0.061344
# passProbability                         0.099662         -0.127504
# preSnapHomeTeamWinProbability           0.031425          0.491263
# preSnapVisitorTeamWinProbability       -0.031425         -0.491263
# homeTeamWinProbabilityAdded             0.004295         -0.036040
# visitorTeamWinProbilityAdded           -0.004295          0.036040
# tackle                                  0.011979         -0.010808
# assist                                 -0.034366          0.004286
# frameId                                -0.005196         -0.001029
# time                                   -0.037197          0.162284
# s                                       0.047526         -0.017313
# a                                       0.023470         -0.008932
# dis                                     0.047603         -0.018973
# o                                      -0.012185          0.032808
# dir                                    -0.015639         -0.022151
#
#                                   preSnapVisitorScore  defendersInTheBox  \
# quarter                                      0.657620          -0.090144
# down                                         0.028971          -0.101572
# yardsToGo                                    0.013621          -0.213700
# yardlineNumber                               0.001085          -0.096164
# preSnapHomeScore                             0.417302          -0.061344
# preSnapVisitorScore                          1.000000          -0.064442
# defendersInTheBox                           -0.064442           1.000000
# passProbability                             -0.005941          -0.463645
# preSnapHomeTeamWinProbability               -0.486317          -0.020883
# preSnapVisitorTeamWinProbability             0.486317           0.020883
# homeTeamWinProbabilityAdded                  0.000517          -0.002753
# visitorTeamWinProbilityAdded                -0.000517           0.002753
# tackle                                       0.009134          -0.024650
# assist                                      -0.024492           0.044252
# frameId                                     -0.007855           0.081714
# time                                        -0.097018           0.083871
# s                                           -0.006192          -0.106336
# a                                           -0.004113          -0.125177
# dis                                         -0.005238          -0.106209
# o                                            0.004772           0.021808
# dir                                         -0.018557           0.007786
#
#                                   passProbability  \
# quarter                                 -0.118828
# down                                     0.321263
# yardsToGo                                0.165595
# yardlineNumber                           0.099662
# preSnapHomeScore                        -0.127504
# preSnapVisitorScore                     -0.005941
# defendersInTheBox                       -0.463645
# passProbability                          1.000000
# preSnapHomeTeamWinProbability           -0.097972
# preSnapVisitorTeamWinProbability         0.097972
# homeTeamWinProbabilityAdded              0.072045
# visitorTeamWinProbilityAdded            -0.072045
# tackle                                   0.036938
# assist                                  -0.063958
# frameId                                 -0.126445
# time                                    -0.049907
# s                                        0.143987
# a                                        0.142099
# dis                                      0.143956
# o                                        0.009773
# dir                                      0.008109
#
#                                   preSnapHomeTeamWinProbability  \
# quarter                                                0.086341
# down                                                  -0.055746
# yardsToGo                                              0.011835
# yardlineNumber                                         0.031425
# preSnapHomeScore                                       0.491263
# preSnapVisitorScore                                   -0.486317
# defendersInTheBox                                     -0.020883
# passProbability                                       -0.097972
# preSnapHomeTeamWinProbability                          1.000000
# preSnapVisitorTeamWinProbability                      -1.000000
# homeTeamWinProbabilityAdded                           -0.034387
# visitorTeamWinProbilityAdded                           0.034387
# tackle                                                -0.023759
# assist                                                 0.044185
# frameId                                               -0.008527
# time                                                   0.223970
# s                                                     -0.016780
# a                                                     -0.003288
# dis                                                   -0.019128
# o                                                      0.029204
# dir                                                   -0.004870
#
#                                   preSnapVisitorTeamWinProbability  ...  \
# quarter                                                  -0.086341  ...
# down                                                      0.055746  ...
# yardsToGo                                                -0.011835  ...
# yardlineNumber                                           -0.031425  ...
# preSnapHomeScore                                         -0.491263  ...
# preSnapVisitorScore                                       0.486317  ...
# defendersInTheBox                                         0.020883  ...
# passProbability                                           0.097972  ...
# preSnapHomeTeamWinProbability                            -1.000000  ...
# preSnapVisitorTeamWinProbability                          1.000000  ...
# homeTeamWinProbabilityAdded                               0.034387  ...
# visitorTeamWinProbilityAdded                             -0.034387  ...
# tackle                                                    0.023759  ...
# assist                                                   -0.044185  ...
# frameId                                                   0.008527  ...
# time                                                     -0.223970  ...
# s                                                         0.016780  ...
# a                                                         0.003288  ...
# dis                                                       0.019128  ...
# o                                                        -0.029204  ...
# dir                                                       0.004870  ...
#
#                                   visitorTeamWinProbilityAdded    tackle  \
# quarter                                               0.026866 -0.004263
# down                                                  0.022881  0.033815
# yardsToGo                                            -0.035253 -0.006896
# yardlineNumber                                       -0.004295  0.011979
# preSnapHomeScore                                      0.036040 -0.010808
# preSnapVisitorScore                                  -0.000517  0.009134
# defendersInTheBox                                     0.002753 -0.024650
# passProbability                                      -0.072045  0.036938
# preSnapHomeTeamWinProbability                         0.034387 -0.023759
# preSnapVisitorTeamWinProbability                     -0.034387  0.023759
# homeTeamWinProbabilityAdded                          -1.000000  0.003606
# visitorTeamWinProbilityAdded                          1.000000 -0.003606
# tackle                                               -0.003606  1.000000
# assist                                                0.010090 -0.716759
# frameId                                               0.011871 -0.108500
# time                                                  0.011270 -0.000494
# s                                                     0.034449  0.142748
# a                                                    -0.000767  0.071062
# dis                                                   0.034789  0.143636
# o                                                     0.006523  0.022934
# dir                                                  -0.008298  0.009644
#
#                                     assist   frameId      time         s  \
# quarter                          -0.010638  0.011445  0.004730 -0.021146
# down                             -0.055171 -0.072899  0.022776  0.057199
# yardsToGo                         0.017317 -0.011410 -0.006137  0.047349
# yardlineNumber                   -0.034366 -0.005196 -0.037197  0.047526
# preSnapHomeScore                  0.004286 -0.001029  0.162284 -0.017313
# preSnapVisitorScore              -0.024492 -0.007855 -0.097018 -0.006192
# defendersInTheBox                 0.044252  0.081714  0.083871 -0.106336
# passProbability                  -0.063958 -0.126445 -0.049907  0.143987
# preSnapHomeTeamWinProbability     0.044185 -0.008527  0.223970 -0.016780
# preSnapVisitorTeamWinProbability -0.044185  0.008527 -0.223970  0.016780
# homeTeamWinProbabilityAdded      -0.010090 -0.011871 -0.011270 -0.034449
# visitorTeamWinProbilityAdded      0.010090  0.011871  0.011270  0.034449
# tackle                           -0.716759 -0.108500 -0.000494  0.142748
# assist                            1.000000  0.012109 -0.009287 -0.153157
# frameId                           0.012109  1.000000 -0.000278  0.052079
# time                             -0.009287 -0.000278  1.000000  0.011534
# s                                -0.153157  0.052079  0.011534  1.000000
# a                                -0.081597  0.057110 -0.003484  0.246415
# dis                              -0.153588  0.060870  0.011717  0.995403
# o                                -0.010669  0.043678  0.032231  0.006044
# dir                              -0.002553  0.030902 -0.009552 -0.001484
#
#                                          a       dis         o       dir
# quarter                          -0.014673 -0.019706  0.017287 -0.032656
# down                              0.052188  0.058002  0.024167  0.003554
# yardsToGo                         0.063469  0.046967 -0.003324  0.004571
# yardlineNumber                    0.023470  0.047603 -0.012185 -0.015639
# preSnapHomeScore                 -0.008932 -0.018973  0.032808 -0.022151
# preSnapVisitorScore              -0.004113 -0.005238  0.004772 -0.018557
# defendersInTheBox                -0.125177 -0.106209  0.021808  0.007786
# passProbability                   0.142099  0.143956  0.009773  0.008109
# preSnapHomeTeamWinProbability    -0.003288 -0.019128  0.029204 -0.004870
# preSnapVisitorTeamWinProbability  0.003288  0.019128 -0.029204  0.004870
# homeTeamWinProbabilityAdded       0.000767 -0.034789 -0.006523  0.008298
# visitorTeamWinProbilityAdded     -0.000767  0.034789  0.006523 -0.008298
# tackle                            0.071062  0.143636  0.022934  0.009644
# assist                           -0.081597 -0.153588 -0.010669 -0.002553
# frameId                           0.057110  0.060870  0.043678  0.030902
# time                             -0.003484  0.011717  0.032231 -0.009552
# s                                 0.246415  0.995403  0.006044 -0.001484
# a                                 1.000000  0.244456  0.012846  0.017058
# dis                               0.244456  1.000000  0.005368 -0.001863
# o                                 0.012846  0.005368  1.000000  0.313731
# dir                               0.017058 -0.001863  0.313731  1.000000
#
# [21 rows x 21 columns]

# %%
## Modeling
# Feature Importance Analysis
# Drop rows with NaN values
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier, VotingClassifier


# final_dff.dropna(inplace=True)
# Define features (X) and target variable (y)
X = final_df.drop(['x','y'], axis=1)
Y_x= final_df['x']
Y_y = final_df['y']

# Y = final_df[['x', 'y']]  # Assuming you have two output coordinates

# Split the dataset into training and testing sets
# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Split the data into training and testing sets
X_train, X_test,Y_x_train,Y_x_test,Y_y_train,Y_y_test = train_test_split(X,Y_x,Y_y,test_size=0.2, random_state=42)
# Create a Random Forest Classifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 74400 entries, 47071 to 18632
# Data columns (total 21 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   quarter                           74400 non-null  int64
#  1   down                              74400 non-null  int64
#  2   yardsToGo                         74400 non-null  int64
#  3   yardlineNumber                    74400 non-null  int64
#  4   preSnapHomeScore                  74400 non-null  int64
#  5   preSnapVisitorScore               74400 non-null  int64
#  6   defendersInTheBox                 74384 non-null  float64
#  7   passProbability                   71989 non-null  float64
#  8   preSnapHomeTeamWinProbability     74400 non-null  float64
#  9   preSnapVisitorTeamWinProbability  74400 non-null  float64
#  10  homeTeamWinProbabilityAdded       74400 non-null  float64
#  11  visitorTeamWinProbilityAdded      74400 non-null  float64
#  12  tackle                            74400 non-null  float64
#  13  assist                            74400 non-null  float64
#  14  frameId                           74400 non-null  float64
#  15  time                              74400 non-null  int64
#  16  s                                 74400 non-null  float64
#  17  a                                 74400 non-null  float64
#  18  dis                               74400 non-null  float64
#  19  o                                 74400 non-null  float64
#  20  dir                               74400 non-null  float64
# dtypes: float64(14), int64(7)
# memory usage: 12.5 MB

# %%
Y_x_train
# Y_train
# Out:
# 47071    61.69
# 46203    41.48
# 84394    40.94
# 2396     82.74
# 77356    11.34
#          ...
# 7170      19.3
# 64093    63.31
# 89866    45.45
# 959      18.52
# 18632     77.7
# Name: x, Length: 74400, dtype: object

# %%
from sklearn.impute import SimpleImputer

# Example: Impute missing values with mean
imputer = SimpleImputer(strategy='mean')
X_train = imputer.fit_transform(X_train)
X_test = imputer.fit_transform(X_test)

# %%
Y_x_test = Y_x_test[:len(X_test)]
Y_x_test = Y_y_test[:len(X_test)]

# Y_test = Y_test[:len(X_test)]

# %%
# # Fit the model
# rf_classifier.fit(X_train, Y_x_train)
# # Get feature importances
# feature_importances = rf_classifier.feature_importances_
# # Create a DataFrame to visualize feature importances
# feature_importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importances})
# # Sort the DataFrame by importance
# feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
# # Plot the feature importances
# plt.figure(figsize=(10, 6))
# plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
# plt.xlabel('Importance')
# plt.title('Feature Importances')
# plt.show()

# %%
# threshold = 0.05
# # Filter features above the threshold
# selected_features = feature_importance_df[feature_importance_df['Importance'] >= threshold]['Feature']
# # Subset the original DataFrame with the selected features
# X_selected = X[selected_features]
# print(X_selected)
# # Split the data into training and testing sets
# X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=42)
# print('X_train:')
# print(X_train)
# print('X_test:')
# print(X_test)
# print('y_train:')
# print(y_train)
# print('y_test:')
# print(y_test)

# %%
# from sklearn.feature_selection import SelectKBest, f_classif

# # Select all features
# selector = SelectKBest(score_func=f_classif, k='all')
# X_train_selected = selector.fit_transform(X_train, Y_x_train)
# X_test_selected = selector.transform(X_test)

# # Now, train your logistic regression model on the selected features
# model1.fit(X_train_selected, Y_x_train)
# predictions = model1.predict(X_test_selected)

# %%
# Y_train = Y_train.to_numpy()

# Y_train = Y_train.reshape(-1,)

# %%
# Logistic Regression Model
# Initialize the Logistic Regression model
model1 = LogisticRegression()
# # Train the model
# model1.fit(X_train, Y_x_train)
# # Make predictions on the test set
# predictions = model1.predict(X_test)
# # Evaluate accuracy
# accuracy = accuracy_score(Y_x_test, predictions)
# print(f"Accuracy of the model using Logistic Regresssion Classifier: {accuracy}")

# %%
# Reduce the training data size
X_train = X_train[:int(0.8 * len(X_train))]
Y_x_train = Y_x_train[:int(0.8 * len(Y_x_train))]
Y_y_train = Y_y_train[:int(0.8 * len(Y_y_train))]
# Y_train = Y_train[:int(0.8 * len(Y_train))]


# Train the model
model1.fit(X_train, Y_x_train)

# Make predictions on the test set
predictions = model1.predict(X_test[:len(Y_x_test)])

# Evaluate accuracy
accuracy = accuracy_score(Y_x_test, predictions)
print(f"Accuracy of the model using Logistic Regresssion Classifier: {accuracy}")
# Out:
# Accuracy of the model using Logistic Regresssion Classifier: 0.0

# %%
predictions,Y_x_test
# Out:
# (array(['79.19', '79.19', '79.19', ..., '79.19', '79.19', '79.19'],
#        dtype=object),
#  41643    28.31
#  46672    27.54
#  44798    30.57
#  91220    25.58
#  26903    34.61
#           ...
#  10814    18.51
#  31233    28.95
#  7817     21.78
#  42690    27.38
#  91153    19.31
#  Name: y, Length: 18601, dtype: object)

# %%
# Random Forest Model
# Initialize the Random Forest model
model2 = RandomForestClassifier(n_estimators=100, random_state=42)
# Train the model
model2.fit(X_train, Y_x_train)
# Make predictions on the test set
predictions = model2.predict(X_test)
# Evaluate accuracy
accuracy = accuracy_score(Y_x_test, predictions)
print(f"Accuracy of the model using Random Forest Classifier : {accuracy}")

# %%
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

model1 = DecisionTreeClassifier(random_state=42)
# Train the model
model1.fit(X_train, y_train)
# Make predictions on the test set
predictions = model1.predict(X_test)
# Evaluate accuracy
accuracy = accuracy_score(y_test, predictions)
print(f"Accuracy of the model using Decision Tree Classifier : {accuracy}")

# %%
# from xgboost import XGBClassifier
# from sklearn.metrics import accuracy_score

# # XGBoost Model
# # Initialize the XGBoost model
# model_xgboost = XGBClassifier(random_state=42,learning_rate =0.01 )
# # Train the model
# model_xgboost.fit(X_train, y_train)
# # Make predictions on the test set
# predictions_xgboost = model_xgboost.predict(X_test)
# # Evaluate accuracy
# accuracy_xgboost = accuracy_score(y_test, predictions_xgboost)
# print(f"Accuracy of the model using XGBoost Classifier: {accuracy_xgboost}")

# %%
model_xgboost_=XGBClassifier(
 learning_rate =0.01,
 n_estimators=300,
 max_depth=7,
 gamma=1,
 subsample=0.8,
 colsample_bytree=0.95,
 nthread=4,
 scale_pos_weight=1,
 seed=42)
model_xgboost_.fit(X_train, y_train)
# Make predictions on the test set
predictions_xgboost_ = model_xgboost_.predict(X_test)
# Evaluate accuracy
accuracy_xgboost = accuracy_score(y_test, predictions_xgboost_)
print(f"Accuracy of the model using XGBoost Classifier: {accuracy_xgboost}")

# %%
# pip install catboost

# %%
# from catboost import CatBoostClassifier


# from sklearn.metrics import accuracy_score

# # CatBoost Model
# # Initialize the CatBoost model
# model_catboost = CatBoostClassifier(random_state=42, verbose=0)  # Set verbose to 0 to suppress training info
# # Train the model
# model_catboost.fit(X_train, y_train)
# # Make predictions on the test set
# predictions_catboost = model_catboost.predict(X_test)
# # Evaluate accuracy
# accuracy_catboost = accuracy_score(y_test, predictions_catboost)
# print(f"Accuracy of the model using CatBoost Classifier: {accuracy_catboost}")
